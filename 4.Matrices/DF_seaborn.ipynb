# %% [markdown]
# ### Introduction to SEABORN

# %%
import os
os.getcwd()
# Out:
# '/Users/arunmuniganti/Desktop/Python Programming Course/4.Matrices'

# %%
import pandas as pd
stats = pd.read_csv('/Users/arunmuniganti/Desktop/Python Programming Course/4.Matrices/DemographicData.csv')
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.columns = ['CountryName', 'CountryCode','Birthrate','InternetUsers','IncomeGroup']
stats
# Out:
#               CountryName CountryCode  Birthrate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %% [markdown]
# ### Distribution

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize']=10,8
import warnings
warnings.filterwarnings('ignore')

# %%
vis1 = sns.distplot(stats['InternetUsers'])

# %%
vis1 = sns.distplot(stats['InternetUsers'], bins=30)

# %% [markdown]
# ### Boxplots

# %%
stats.head(2)
# Out:
#    CountryName CountryCode  Birthrate  InternetUsers  IncomeGroup
# 0        Aruba         ABW     10.244           78.9  High income
# 1  Afghanistan         AFG     35.253            5.9   Low income

# %%
vis2 = sns.boxplot(data=stats, x='IncomeGroup', y='Birthrate')
vis2
# Out:
# <Axes: xlabel='IncomeGroup', ylabel='Birthrate'>

# %% [markdown]
# ### Seaborn gallery

# %% [raw]
# https://seaborn.pydata.org/examples/index.html

# %%
stats
# Out:
#               CountryName CountryCode  Birthrate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
vis3 = sns.lmplot(x='InternetUsers', y='Birthrate', data=stats)

# %%
vis4 = sns.lmplot(x='InternetUsers', y='Birthrate', data=stats, fit_reg=False)

# %%
vis5 = sns.lmplot(x='InternetUsers', y='Birthrate', data=stats, fit_reg=False, hue='IncomeGroup')

# %%
vis5 = sns.lmplot(x='InternetUsers', y='Birthrate', data=stats, fit_reg=False, hue='IncomeGroup', height=8)

# %%
vis5 = sns.lmplot(x='InternetUsers', y='Birthrate', data=stats, fit_reg=False, hue='IncomeGroup', height=8, scatter_kws={"s":150})
